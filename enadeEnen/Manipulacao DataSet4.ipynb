# %%
import numpy as np
import os
import pandas as pd
import gc

# %%
past = 'Enem/DataSet_ENEM/'

# %%
files = os.listdir(past)
df = {}

cols = ['SG_UF_PROVA', 'UF_MUNICIPIO_PROVA', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT', 
          'NU_NOTA_COMP1', 'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4', 'NU_NOTA_COMP5']

# %%
dft2011 = pd.DataFrame()
for chunk in pd.read_csv(past + 'dft2011.csv', encoding = 'Latin1', 
                             sep = ';', chunksize=300000,  low_memory = False):
        dft2011 = pd.concat([dft2011, chunk], ignore_index=True)
        del chunk; gc.collect()

# %%
dft = pd.DataFrame()
for chunk in pd.read_csv(past + 'dft.csv', encoding = 'Latin1', 
                             sep = ',', chunksize=300000,  low_memory = False):
        dft = pd.concat([dft, chunk], ignore_index=True)
        del chunk; gc.collect()
# Out:
# Index(['NU_INSCRICAO', 'NU_ANO', 'IDADE', 'TP_SEXO', 'COD_MUNICIPIO_INSC',
#        'NO_MUNICIPIO_INSC', 'UF_INSC', 'ST_CONCLUSAO', 'ANO_CONCLUIU',
#        'TP_ESCOLA', 'IN_TP_ENSINO', 'TP_ESTADO_CIVIL', 'TP_COR_RACA',
#        'IN_UNIDADE_HOSPITALAR', 'IN_BAIXA_VISAO', 'IN_CEGUEIRA', 'IN_SURDEZ',
#        'IN_DEFICIENCIA_AUDITIVA', 'IN_SURDO_CEGUEIRA', 'IN_DEFICIENCIA_FISICA',
#        'IN_DEFICIENCIA_MENTAL', 'IN_DEFICIT_ATENCAO', 'IN_DISLEXIA',
#        'IN_GESTANTE', 'IN_LACTANTE', 'IN_IDOSO', 'IN_AUTISMO', 'IN_SABATISTA',
#        'IN_BRAILLE', 'IN_AMPLIADA', 'IN_LEDOR', 'IN_ACESSO', 'IN_TRANSCRICAO',
#        'IN_LIBRAS', 'IN_LEITURA_LABIAL', 'IN_MESA_CADEIRA_RODAS',
#        'IN_MESA_CADEIRA_SEPARADA', 'IN_APOIO_PERNA', 'IN_GUIA_INTERPRETE',
#        'IN_CERTIFICADO', 'NO_ENTIDADE_CERTIFICACAO',
#        'UF_ENTIDADE_CERTIFICACAO', 'PK_COD_ENTIDADE', 'COD_MUNICIPIO_ESC',
#        'NO_MUNICIPIO_ESC', 'UF_ESC', 'ID_DEPENDENCIA_ADM', 'ID_LOCALIZACAO',
# ...

# %%
dft.columns
# Out:
# Index(['151', '152', '153', '154', '155', '156', '157', '158', '159', '160',
#        '161', '162', '163', '164', '165', '166', '167', '168', '169', '170',
#        '1'],
#       dtype='object')

# %%
dft = dft.drop(columns=['161', '162', '163', '164', '165', '166', '167', '168', '169', '170'])
dft
# Out:
#                                                          1
# 0            SP1111   577.10   576.00   575.50   737.10...
# 1        PR0000 .   .   .   .  1211171251290DCEACDBECBC...
# 2           RS1111   491.40   435.30   491.60   467.80E...
# 3           RJ1111   424.40   422.40   360.80   406.70D...
# 4         CE1111   648.80   583.20   571.50   769.30AAC...
# ...                                                    ...
# 5380851    1111   324.10   373.80   402.20   358.70CAEB...
# 5380852    1111   362.30   404.00   441.80   392.90EDEC...
# 5380853    1111   339.00   382.70   492.10   470.60CECD...
# 5380854    1111   362.70   466.40   343.50   385.90CEEC...
# 5380855    1111   314.70   387.20   494.70   584.90EECE...
#
# [5380856 rows x 1 columns]

# %%
dft = dft.fillna('')

# %%
dft['1'] = dft['1'] + dft['124'] + dft['125'] + dft['126'] + dft['127']+ dft['128'] + dft['129'] + dft['130']

# %%
print(dft['1'][0])
# Out:
#     SP1111   577.10   576.00   575.50   737.   140.00   140.00   140.00   140.00    60.00   620.000 .  . .

# %%
a = dft['1'].str.split(expand = True)

# %%
a[12]
# Out:
# 0             .
# 1          None
# 2             .
# 3             .
# 4             .
#            ...
# 5380851       .
# 5380852    None
# 5380853       .
# 5380854       .
# 5380855       .
# Name: 12, Length: 5380856, dtype: object

# %%
col = ['NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT', 'NU_NOTA_COMP1', 
       'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4', 'NU_NOTA_COMP5']
dft20112 = pd.DataFrame(b.T, columns = col)

# %%
dft2011
# Out:
#         NU_NOTA_CN NU_NOTA_CH NU_NOTA_LC NU_NOTA_MT  \
# 0           577.10     576.00     575.50     737.10
# 1                .          .          .          .
# 2           491.40     435.30     491.60     467.80
# 3           424.40     422.40     360.80     406.70
# 4           648.80     583.20     571.50     769.30
# ...            ...        ...        ...        ...
# 5380851     324.10     373.80     402.20     358.70
# 5380852     362.30     404.00     441.80     392.90
# 5380853     339.00     382.70     492.10     470.60
# 5380854     362.70     466.40     343.50     385.90
# 5380855     314.70     387.20     494.70     584.90
#
#                                              NU_NOTA_COMP1 NU_NOTA_COMP2  \
# 0                                                   140.00        140.00
# 1        1211171251290DCEACDBECBCAEBACBEAECEDEDAABDBEDB...             .
# 2                                                   140.00         60.00
# ...

# %%
np.shape(b
# Out:
#          Unnamed: 0  SG_UF_PROVA     UF_MUNICIPIO_PROVA
# 0                 0         2011  SAO BERNARDO DO CAMPO
# 1                 1         2011   SAO JOSE DOS PINHAIS
# 2                 2         2011           PORTO ALEGRE
# 3                 3         2011           BELFORD ROXO
# 4                 4         2011              FORTALEZA
# ...             ...          ...                    ...
# 5380851     5380851         2011           JUIZ DE FORA
# 5380852     5380852         2011           JUIZ DE FORA
# 5380853     5380853         2011   SAO JOAQUIM DE BICAS
# 5380854     5380854         2011   SAO JOAQUIM DE BICAS
# 5380855     5380855         2011   SAO JOAQUIM DE BICAS
#
# [5380856 rows x 3 columns]

# %%
pd.concat([dft20112
